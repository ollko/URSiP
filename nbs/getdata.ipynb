# %%
import pandas as pd
from pathlib import Path
file_name = '1.xlsx'

# %%
file = Path.cwd().parent / 'row_data' / file_name
print(file)
# Out:
# /home/korotkaya/me/sobes/get_data_from_exel/row_data/1.xlsx

# %%
df = pd.read_excel(file, header = [0,1,2], index_col = [0], dtype = str)

# %%
df
# Out:
# id            company  fact                   forecast
#    Unnamed: 1_level_1  Qliq        Qoil           Qliq        Qoil
#    Unnamed: 1_level_2 data1 data2 data1 data2    data1 data2 data1 data2
# 1            company1    10    20    30    40       12    22    15    25
# 2            company2    11    21    31    41       13    23    20    30
# 3            company1    12    22    32    42       14    24    25    35
# 4            company2    13    23    33    43       15    25    30    40
# 5            company1    14    24    34    44       16    26    35    45
# 6            company2    15    25    35    45       17    27    40    50
# 7            company1    16    26    36    46       18    28    45    55
# 8            company2    17    27    37    47       19    29    50    60
# 9            company1    18    28    38    48       20    30    55    65
# 10           company2    19    29    39    49       21    31    60    70
# ...

# %%
print(df.columns)
print(df.shape)
# Out:
# MultiIndex([( 'company', 'Unnamed: 1_level_1', 'Unnamed: 1_level_2'),
#             (    'fact',               'Qliq',              'data1'),
#             (    'fact',               'Qliq',              'data2'),
#             (    'fact',               'Qoil',              'data1'),
#             (    'fact',               'Qoil',              'data2'),
#             ('forecast',               'Qliq',              'data1'),
#             ('forecast',               'Qliq',              'data2'),
#             ('forecast',               'Qoil',              'data1'),
#             ('forecast',               'Qoil',              'data2')],
#            names=['id', None, None])
# (20, 9)

# %%
for item in df.columns:
    print(item)
# Out:
# ('company', 'Unnamed: 1_level_1', 'Unnamed: 1_level_2')
# ('fact', 'Qliq', 'data1')
# ('fact', 'Qliq', 'data2')
# ('fact', 'Qoil', 'data1')
# ('fact', 'Qoil', 'data2')
# ('forecast', 'Qliq', 'data1')
# ('forecast', 'Qliq', 'data2')
# ('forecast', 'Qoil', 'data1')
# ('forecast', 'Qoil', 'data2')

# %%
df[[( 'company', 'Unnamed: 1_level_1', 'Unnamed: 1_level_2'),(    'fact',               'Qliq',              'data1')]]
# Out:
# id            company  fact
#    Unnamed: 1_level_1  Qliq
#    Unnamed: 1_level_2 data1
# 1            company1    10
# 2            company2    11
# 3            company1    12
# 4            company2    13
# 5            company1    14
# 6            company2    15
# 7            company1    16
# 8            company2    17
# 9            company1    18
# 10           company2    19
# 11           company1    20
# 12           company2    21
# 13           company1    22
# 14           company2    23
# 15           company1    24
# 16           company2    25
# 17           company1    26
# 18           company2    27
# 19           company1    28
# 20           company2    29
