# %%
import pandas as pd
from pathlib import Path
file_name = '1.xlsx'

# %%
exel_file = Path.cwd() / 'row_data' / file_name
print(file_path)
# Out:
# /home/korotkaya/me/sobes/get_data_from_exel/row_data/1.xlsx

# %%
df = pd.read_excel(exel_file, header = [0,1,2], index_col = [0])

# %%
display(df)
# Out:
# id            company                fact                      \
#    Unnamed: 1_level_1                Qliq
#    Unnamed: 1_level_2 2023-07-14 00:00:00 2023-07-15 00:00:00
# 1            company1                  10                  20
# 2            company2                  11                  21
# 3            company1                  12                  22
# 4            company2                  13                  23
# 5            company1                  14                  24
# 6            company2                  15                  25
# 7            company1                  16                  26
# 8            company2                  17                  27
# 9            company1                  18                  28
# 10           company2                  19                  29
# 11           company1                  20                  30
# 12           company2                  21                  31
# ...
